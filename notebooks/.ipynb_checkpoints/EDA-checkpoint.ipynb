# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
import joblib
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve
import numpy as np

from src.load_data import LoadData
from src.prep_data import PrepData
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f6152a65d8e5> in <module>
#       7 import numpy as np
#       8
# ----> 9 from src.load_data import LoadData
#      10 from src.prep_data import PrepData
#
# ModuleNotFoundError: No module named 'src'

# %%
# Set the name of the file to load, and bring in Loader and Data Prep
loader = LoadData()
prep = PrepData()

df = loader.load_attributedata_to_df()

# %%
# The target for this particular dataset is class
y = df['Class']
X = prep.drop_target_column(df)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.2,
    random_state = 680
)

model = SVC()
model.fit(X_train, y_train)

calibrator = CalibratedClassifierCV(model, cv=10)
calibrator.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(base_estimator=SVC(C=1.0, break_ties=False,
#                                           cache_size=200, class_weight=None,
#                                           coef0=0.0,
#                                           decision_function_shape='ovr',
#                                           degree=3, gamma='scale', kernel='rbf',
#                                           max_iter=-1, probability=False,
#                                           random_state=None, shrinking=True,
#                                           tol=0.001, verbose=False),
#                        cv=10, method='sigmoid')

# %%
svc_disp = plot_roc_curve(model, X_test, y_test)
plt.show()

# %%
# predict probabilities
probs = calibrator.predict_proba(X_test)[:, 1]
# reliability diagram
fop, mpv = calibration_curve(y_test, probs, n_bins=10, normalize=True)
# plot perfectly calibrated
plt.plot([0, 1], [0, 1], linestyle='--')
# plot calibrated reliability
plt.plot(mpv, fop, marker='.')
plt.show()

# %%
# predict probabilities
model.decision_function(X_test)
# reliability diagram
fop, mpv = calibration_curve(y_test, probs, n_bins=10, normalize=True)
# plot perfectly calibrated
plt.plot([0, 1], [0, 1], linestyle='--')
# plot calibrated reliability
plt.plot(mpv, fop, marker='.')
plt.show()

# %%
data = np.random.randint(4, size=(1,54))
data
# Out:
# array([[3, 2, 3, 0, 1, 0, 2, 3, 1, 2, 3, 1, 0, 0, 0, 1, 3, 1, 2, 2, 3, 3,
#         3, 0, 1, 0, 3, 0, 3, 1, 0, 1, 0, 1, 0, 0, 2, 1, 0, 2, 2, 2, 2, 2,
#         0, 3, 3, 3, 1, 0, 3, 1, 1, 1]])

# %%
calibrator.predict_proba(data)
# Out:
# array([[0.36775124, 0.63224876],
#        [0.40716743, 0.59283257],
#        [0.46342316, 0.53657684],
#        [0.50266755, 0.49733245],
#        [0.3938264 , 0.6061736 ],
#        [0.29930466, 0.70069534],
#        [0.40774866, 0.59225134],
#        [0.26800377, 0.73199623],
#        [0.50989548, 0.49010452],
#        [0.42915294, 0.57084706]])

# %%
from src.prep_data import PrepData
from src.predict_data import PredictData
from src.load_data import LoadData

# %%
loader = LoadData()
prep = PrepData()
model = loader.load_model('./models/cal_model.pkl')
predictor = PredictData(model)

# %%
prediction = predictor.predict(data)

# %%
prediction[0][1]
# Out:
# 0.5545058421230364
